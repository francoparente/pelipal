# %%
# %load_ext autoreload

# %%
# %autoreload --print
from backend.src.services.movie_search import MovieSearchService

service = MovieSearchService()

results = service.search_movie('the apprentice')
results
# Out:
# {'source': 'YTS',
#  'data': {'status': 'ok',
#   'status_message': 'Query was successful',
#   'data': {'movie_count': 7,
#    'limit': 20,
#    'page_number': 1,
#    'movies': [{'id': 65614,
#      'url': 'https://yts.mx/movies/the-sorcerers-apprentice-2001',
#      'imdb_code': 'tt0120166',
#      'title': "The Sorcerer's Apprentice",
#      'title_english': "The Sorcerer's Apprentice",
#      'title_long': "The Sorcerer's Apprentice (2001)",
#      'slug': 'the-sorcerers-apprentice-2001',
#      'year': 2001,
#      'rating': 4.2,
#      'runtime': 86,
#      'genres': ['Adventure', 'Family', 'Fantasy'],
#      'summary': '',
#      'description_full': '',
#      'synopsis': '',
#      'yt_trailer_code': 'nNu7ldTynFE',
#      'language': 'en',
#      'mpa_rating': '',
#      'background_image': 'https://yts.mx/assets/images/movies/the_sorcerers_apprentice_2001/background.jpg',
# ...
